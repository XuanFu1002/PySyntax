# %%
# 2024/10/9 (Wed.)
# 這樣.pyplot的寫法是說，only include(import)pyplot class in matplotlib package

# 如果缺package，雖說可以「! pip install {package}」，用"!"告訴interpret這邊要執行bash command，不是language statement
# ，但是這就得很清楚自己是在使用甚麼venv，雖然這邊開發的時候很明確地就指明了用哪個環境，所以其實也無須擔心，但是直接activate venv
# ，然後在裡面安裝，更有親眼所見的安心感

# NOTE: VS Code一樣可以挑選, anaconda3路徑底下envs管理的venv => 歸根結柢，都是電腦上的路徑，所以指定好都可以

import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x,y)
# plt.plot(x,y, marker='o')
plt.title("Line Plot Sample")       # 圖表的名稱
plt.xlabel("X Axis")        # xlable() => 給axis起名 => 這邊給lable不一樣東西
plt.ylabel("Y Axis")

plt.show()

# %%
# matplotlib.pyplot(x, y, .....) => 繪製「一條折線圖」

# matplotlib不是縮寫 => 提供這個library的人，希望為python提供類似於"Matlab"的繪圖軟件功能，所以開頭取名了"mat"
# pyplot提供創建多種圖形 => eg. 折線圖、柱狀圖、散點圖、etc.

# pyplot提供多種options(parameter)，let's experience
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]        # 一組x對應y，當然就只有一條線

# 舉例, 常見參數 => 這裡代入argument的時候，要給清楚，給清楚說哪個variable的value是多少 => 畢竟這邊都是options parameter，所以不給清楚不知道是誰呀 => make sense
# color => 設定直線圖的顏色
# plt.plot(x,y,color="green")         # 可以使用'#FF5733'，反正就是符合rgb，常見用法都行

# linestyle => 折線圖樣式，若不給argument的話，default 「-」，i.e.實線。「- -」：虛線、「-.」:點劃線、「:」:點線
# plt.plot(x,y,linestyle="--")       # 虛線，------
# plt.plot(x,y,linestyle="-.")        # 點劃線，就是先畫一個線在畫一個點 => -.-.-.-.-.-.
# plt.plot(x,y,linestyle=":")       # 點線，......
# ( 觀察下來可以發現，就是傳「連續兩個」長怎樣，後續就依照這個unit做iterate )

# linewidth => 折線圖，線的寬度
# plt.plot(x,y,linewidth=5,linestyle="--",color='red')

# marker => 在數據「節點(node)」處，設計標記樣式
# ('o':圓形、's':方形(square)、'x': 叉號)   => 這邊o、x都是直接形象去意會，s則是單詞縮寫
# plt.plot(x,y,marker='o')        # 這邊case sensity
# plt.plot(x,y,marker='s')        # 這邊也only small capital
# plt.plot(x,y,marker='x')    # ㄜ，這邊小寫是"細"，大寫是"粗"X，至於大小都一樣

# 若想調整，「標記大小」，不是單純粗細，而是size => 那就添加「markersize」options
# plt.plot(x,y,marker='o',markersize='10')

# markerfacecolor => modfiy 標記圖案的「實心」部分，所使用的顏色 => 圖都有分，內、外
# plt.plot(x,y,marker='o',markerfacecolor='yellow')
# markeredgecolor => 這是調整marker外框color
plt.plot(x,y,marker='s',markeredgecolor='red',markersize='10')

# label => 給「某條折線圖」起名
plt.plot(x,y,label='Sample line')
plt.legend()    # 要當配這個

# NOTE: 當statement前後分別出現兩個以上的plot show的時候，這邊會採用「疊加」的方式，並不是用取代，只show最後一個plot的方式

# %%
# plot() options abbreviation, 還支持一個更省略的表達方式 => '<color><marker><linestyle>'
#  => eg. plot(x,y,'ro--') => 表示紅色折線圖，標記點圈圈，折線圖採用虛線
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x,y,'ro--')

# %%
# 接著體驗 帶入不同數據，所畫出的不同plot(折線圖) => sin、cos

# 圓周長 => 2πr(直徑 * π)   
# 弧度(radian, 這是角度) => 2πr / 360, 一整圈的長度，除以一圈的角度，得到的就是，「360度當中1 degree partial的圓周長度」，i.e.弧度
# ( 所以弧度的定義由此可知 => 1 弧度就是在圓周上，當弧的長度等於半徑時的那個角，radius才是弧度長 )

# numpy.sin() => concept, 正弦值 return y/r。 數學中，使用sin、cos等的時候，我們所帶入的parameter是"角度"，
#                目標求「在該角度下，他的sin、cos，i.e. y/r、x/r之間的關係」=> 而這裡return的東西一樣，都是"某角度下，邊之間的關係"
#                => 但這裡所帶入的parameter unit是「radian」
#               ，"關係"這種單位明顯就不是"圖表中某個axis所常見使用的單位" => 所以程式中帶入sin、cos的parameter是"radian(弧度)"
#               ，弧度當中input(domain)，然後輸出"該弧度"
# numpy.cos() => concept, 餘弦值 return x/r。
# numpy.linspace() => return等差數列，default總數50 => linspace不給step parameter，他是透過「總數」去調整公差 => 所以著重的是數量

import matplotlib.pyplot as plt
import numpy as np
import math
theta_in_degrees = 30
theta_in_radians = math.radians(theta_in_degrees)
print(theta_in_radians)
sin_value = math.sin(theta_in_radians)
print(sin_value)
# # x1 = np.linspace(0.0,2*np.pi)     # plot圖扁的橫、縱軸數值顯示，取決於「代如參數的"最小"&"最大"值」 => 0~6..
# x1 = np.linspace(1,10)      # x axis value 0~10 => this is the depedn of plot axis value
# # 計算，x1 set中每個element的正弦數值"y1" => 如此一來就有了，(x,y)axis value，就可以畫plot(折線圖)
# y1 = np.sin(x1)

# x2 = np.linspace(0.0,2*np.pi)
# y2 = np.cos(x2)

# plt.plot(x1, y1, 'r', label='sin')    # 'r' => red
# plt.plot(x2, y2, 'b-o', label='cos')    # 'b-o' => blue, -(實線), o(圓形)
# plt.legend()
# plt.show()
# Out:
# 0.5235987755982988
# 0.49999999999999994

# %%
# Experience, draw curve of sin, cos, exponential,log」
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-5,5)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.exp(x)
y4 = np.log(x)

fig,ax = plt.subplots(2,2)
ax[0, 0].plot(x, y1)  
ax[0, 0].text(0., 0., str((0, 0)), fontsize=18, ha='center')
ax[0, 1].plot(x, y2)  
ax[0, 1].text(0., 0., str((0, 1)), fontsize=18, ha='center')
ax[1, 0].plot(x, y3)  
ax[1, 0].text(0., 75., str((1, 0)), fontsize=18, ha='center')
ax[1, 1].plot(x, y4)  
ax[1, 1].text(2.5, -0.5, str((1, 1)), fontsize=18, ha='center')

# 設定標頭
ax[0, 0].set_title("Sin")
ax[0, 1].set_title("Cos")
ax[1, 0].set_title("Exponential")
ax[1, 1].set_title("log")

fig.tight_layout()
plt.show()
# Out:
# C:\Users\a0903\AppData\Local\Temp\ipykernel_8964\3498354133.py:9: RuntimeWarning: invalid value encountered in log
#   y4 = np.log(x)

# %%
# matplotlib.pyplot.scatter() => 畫「散點圖」
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,10,50)
y = np.sin(x)
plt.scatter(x, y, c='blue', marker = '*')
plt.show()

# %%
# matplotlib.pyplot.gca() => get current axes, axes是一個Object 
#       => Axes是Matplotlib當中的一個「class」，就是OOP那個class concept => eg. return的時候長這樣「Axes(0.125,0.11;0.775x0.77)」
#       => 「0.125,0.11」代表plot中"最左下角的點的位置"；「0.775x0.77」代表 實際劃出的表格 「占用整張圖的比例」

import matplotlib.pyplot as plt
import numpy as np

# x = np.linspace(0,10,dtype=int) default num(amount)=50
x = np.linspace(0,10,100)
y = np.sin(x)
# plt.plot(x,y)

axes = plt.gca()
print(axes)
axes.plot(x,y)       # 說過了,pyplot() function 所return的是一個「Axes class Object」，
                    # 所以object自然可以呼叫function，自於具體提供多少API，去看document即可
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
# 進一步 了解、體驗使用matplotlib.pyplot.gca，使用時機、場景

import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

fig = plt.figure(figsize=(8,6))   # 確實有起到調整，"整張"圖片大小
# plt.plot(x,y1)

ax1 = fig.add_axes([0.1, 0.55, 0.8, 0.4])
ax1.plot(x, y1, label='sin(x)', color='b')                                              #
ax1.set_title('Sin Wave')
ax1.set_xlabel('X-axis')
ax1.set_ylabel('Y-axis')
# ax1.legend()

# 添加「子圖」
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4])  # [左, 下, 寬, 高]
ax2.plot(x, y2, label='cos(x)', color='r')
ax2.set_title('Cosine Wave')
ax2.set_xlabel('X-axis')
ax2.set_ylabel('Y-axis')
# ax2.legend()

plt.tight_layout()  # 自動調整子圖間距
plt.show()

print()
# Out:
# C:\Users\a0903\AppData\Local\Temp\ipykernel_30152\1220106228.py:28: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()  # 自動調整子圖間距
